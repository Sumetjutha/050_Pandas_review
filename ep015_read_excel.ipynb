# %%
# !pip install xlrd

# %%
# !pip install openpyxl

# %%
import pandas as pd

# %%
df = pd.read_excel('data_result/dataupdate.xlsx','weather')

# %%
df.head(3)
# Out:
#          Day  Temperature  WindSpeed    Event
# 0 2020-12-01           30          9  แดดร้อน
# 1 2020-12-02           28          8   เมฆมาก
# 2 2020-12-03           27          4     ฝนตก

# %%
df = pd.read_excel('data_result/dataupdate.xlsx','weather',index_col='Day')

# %%
df
# Out:
#             Temperature  WindSpeed    Event
# Day
# 2020-12-01           30          9  แดดร้อน
# 2020-12-02           28          8   เมฆมาก
# 2020-12-03           27          4     ฝนตก
# 2020-12-04           19          3  แดดร้อน
# 2020-12-05           20          5   เมฆมาก
# 2020-12-06           25          6     ฝนตก
# 2020-12-07           36          4     ฝนตก
# 2020-12-08           28          6     ฝนตก
# 2020-12-09           17          5   เมฆมาก
# 2020-12-10           24          6  แดดร้อน
# 2020-12-11           26          4     ฝนตก
# 2020-12-12           27          9  แดดร้อน
# 2020-12-13           30          2  แดดร้อน
# 2020-12-14           31          5   เมฆมาก
# 2020-12-15           28          4  แดดร้อน
# 2020-12-16           27          7  แดดร้อน
# 2020-12-17           20          8     ฝนตก
# 2020-12-18           18          5     ฝนตก
# 2020-12-19           25          7  แดดร้อน
# 2020-12-20           28          4   เมฆมาก
# ...

# %%
df = pd.read_excel('data_result/dataupdate.xlsx','Product',index_col='Name')

# %%
df
# Out:
#                              Category    Price
# Name
# เมาส์              อุปกรณ์คอมพิวเตอร์    900.0
# ปากกา                 อุปกรณ์การเรียน      NaN
# โคมไฟ                             NaN      NaN
# ไมโครโฟน                          NaN    750.0
# เครื่องซักผ้า         เครื่องใช้ไฟฟ้า      NaN
# เสื้อยืดคอกลม                เสื้อผ้า    500.0
# กางเกงยีนต์                  เสื้อผ้า      NaN
# ตุ๊กตาหมีพูห์                 ของเล่น    950.0
# โซฟา                     เฟอร์นิเจอร์   5000.0
# จาน                       เครื่องครัว    250.0
# ทีวี                  เครื่องใช้ไฟฟ้า  15000.0
# ยางลบ                 อุปกรณ์การเรียน      NaN
# External HardDisk  อุปกรณ์คอมพิวเตอร์   2500.0
# คีย์บอร์ด          อุปกรณ์คอมพิวเตอร์    850.0
# รถบังคับ                      ของเล่น      NaN
